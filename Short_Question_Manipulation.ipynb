# %% [markdown]
# <a href="https://colab.research.google.com/github/AITeamAdmin/TlvLLM_Search/blob/main/Short_Question_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git remote add origin git@github.com:AITeamAdmin/TlvLLM_Search.git
# !git branch -M main
# !git push -u origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 43.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 44.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 74.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.1 MB/s eta 0:00:00
# ...

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.neighbors import NearestNeighbors
import pandas as pd

# %%
#Define the model. Either from scratch of by loading a pre-trained model
model_real = SentenceTransformer('intfloat/multilingual-e5-large')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/160k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/690 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# ...

# %%
df = pd.read_csv("/content/drive/MyDrive/TLV/LLM_project/short_result.csv")

# %%
df_content_item = pd.read_csv("/content/drive/MyDrive/TLV/LLM_project/content_item.csv")

# %%
df_full_q = pd.read_csv("/content/drive/MyDrive/TLV/LLM_project/result.csv")

# %%
df
# Out:
#        Index                                     Short Question
# 0          0  יתרונות של חקלאות אורבנית לילדים: חינוך סביבתי...
# 1          1  חקלאות עירונית: השתלמות בחקלאות בערים. יתרונות...
# 2          2        פעילות חקלאות אורבנית לילדים בדיזנגוף סנטר.
# 3          3  אפשרויות השתתפות בתכנית חקלאות אורבנית בתל אבי...
# 4          4          הקמת חקלאות אורבנית בעיר בסיוע של 65 ש"ח.
# ...      ...                                                ...
# 12084  14680  Error code: 429 - {'error': {'message': 'Rate ...
# 12085  14681                      שימור מארכיטקטוני של בית ספר.
# 12086  14682  Error code: 429 - {'error': {'message': 'Rate ...
# 12087  14683                            פרוייקט בניית רכב חשמלי
# 12088  14684  Error code: 429 - {'error': {'message': 'Rate ...
#
# [12089 rows x 2 columns]

# %%
short_question = df.drop(df[df['Short Question'].str.contains('Error code: 429')].index)

# %%
short_question
# Out:
#        Index                                     Short Question
# 0          0  יתרונות של חקלאות אורבנית לילדים: חינוך סביבתי...
# 1          1  חקלאות עירונית: השתלמות בחקלאות בערים. יתרונות...
# 2          2        פעילות חקלאות אורבנית לילדים בדיזנגוף סנטר.
# 3          3  אפשרויות השתתפות בתכנית חקלאות אורבנית בתל אבי...
# 4          4          הקמת חקלאות אורבנית בעיר בסיוע של 65 ש"ח.
# ...      ...                                                ...
# 12077  14673                          סכום תכנית שימור בית ספר.
# 12080  14676             תוכנית לשימור בית ספר בשכונת צפון ישן.
# 12083  14679                         שימור ושיפור הסביבה הטבעית
# 12085  14681                      שימור מארכיטקטוני של בית ספר.
# 12087  14683                            פרוייקט בניית רכב חשמלי
#
# [10746 rows x 2 columns]

# %%
df_full_q_r = df_full_q.reset_index()

# %%
df_full_q_r
# Out:
#        index                                 Generated Question     Item  \
# 0          0      מהן היתרונות של חקלאות אורבנית לילדות וילדים?  2353_14
# 1          1  מהו מהגדרת החקלאות אורבנית ואילו יתרונות ישנים...  2353_14
# 2          2  מהו פעילות החקלאות האורבנית המוצעת עבור ילדים ...  2353_14
# 3          3  מהם האפשרויות להשתתף בתכנית חקלאות אורבנית ליל...  2353_14
# 4          4  אילו צעדים נדרשים לסייע בהקמת חקלאות אורבנית ל...  2353_14
# ...      ...                                                ...      ...
# 14680  14680  מהו סוג הפרוייקט שנערך לתכנית לשימור בית הספר ...    335_3
# 14681  14681  מהו הפרוייקט המיוחד שתכנית לשימור בית הספר תל ...    335_3
# 14682  14682  מהו המטרה של תכנית השימור של בית הספר תל נורדא...    335_3
# 14683  14683         מהו סוג הפרוייקט שנערך בבית ספר תל נורדאו?    335_3
# 14684  14684  מהו תוכן תכנית השמירה והשיפוץ שאושרה לבית ספר ...    335_3
#
#        Index
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...

# %%
# prompt: Using dataframe df_full_q_r: inner join between df_full_q_r field index and short_question Index

inned_df = pd.merge(df_full_q_r, short_question, left_on='index', right_on='Index', how='inner')

# %%
inned_df
# Out:
#        index                                 Generated Question     Item  \
# 0          0      מהן היתרונות של חקלאות אורבנית לילדות וילדים?  2353_14
# 1          1  מהו מהגדרת החקלאות אורבנית ואילו יתרונות ישנים...  2353_14
# 2          2  מהו פעילות החקלאות האורבנית המוצעת עבור ילדים ...  2353_14
# 3          3  מהם האפשרויות להשתתף בתכנית חקלאות אורבנית ליל...  2353_14
# 4          4  אילו צעדים נדרשים לסייע בהקמת חקלאות אורבנית ל...  2353_14
# ...      ...                                                ...      ...
# 10741  14673         מהו סכום התכנית לשימור בית הספר תל נורדאו?    335_3
# 10742  14676  מהו תוכן התכנית לשימור בית ספר תל נורדאו בשכונ...    335_3
# 10743  14679   מהו היעד של תכנית השימור של בית הספר בתל נורדאו?    335_3
# 10744  14681  מהו הפרוייקט המיוחד שתכנית לשימור בית הספר תל ...    335_3
# 10745  14683         מהו סוג הפרוייקט שנערך בבית ספר תל נורדאו?    335_3
#
#        Index_x  Index_y                                     Short Question
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
embeddings = model_real.encode(short_question)

# %%
# מודל KNN
knn = NearestNeighbors(n_neighbors=1)
knn.fit(embeddings)

# %%
indexs = []
for emb in embeddings_q:
    distances, indices = knn.kneighbors([emb])
    indexs.append(indices)
